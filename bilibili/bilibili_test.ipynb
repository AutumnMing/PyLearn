# %%
from requests import get as res_get
from time import time, sleep
from datetime import datetime
from pprint import pprint

# %% [markdown]
# ### B站评论时间戳参数

# %%
t1 = 1672656320437
datetime.fromtimestamp(t1/1000)
# Out:
# datetime.datetime(2023, 1, 2, 18, 45, 20, 437000)

# %%
sleep(5)
int(time() * 1000)
# Out:
# 1672730101269

# %%
'''https://api.bilibili.com/x/v2/reply/main?callback=jQuery17204955026459262257_1672647817430&jsonp=jsonp&next=90277&type=1&oid=476022007&mode=2&plat=1&_=1672657410311'''
# Out:
# 'https://api.bilibili.com/x/v2/reply/main?callback=jQuery17204955026459262257_1672647817430&jsonp=jsonp&next=90277&type=1&oid=476022007&mode=2&plat=1&_=1672657410311'

# %%
'''https://api.bilibili.com/x/v2/reply/main?next=90041&type=1&oid=476022007&mode=3&plat=1'''
# Out:
# 'https://api.bilibili.com/x/v2/reply/main?next=90041&type=1&oid=476022007&mode=3&plat=1'

# %%
# 分析出payload中的有用参数
url = 'https://api.bilibili.com/x/v2/reply/main?'
params = {
    'next':'9',
    'type':'1',
    'oid':'476022007',
    'mode':'3',
    'plat':'1'
}
headers = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}

# %%
r = res_get(url, params=params, headers=headers)
print(r.status_code)
print(r.json())
# Out:
# 200
# {'code': 0, 'message': '0', 'ttl': 1, 'data': {'cursor': {'is_begin': False, 'prev': 9, 'next': 10, 'is_end': False, 'all_count': 84474, 'mode': 3, 'support_mode': [2, 3], 'name': '热门评论'}, 'replies': [{'rpid': 141534734384, 'oid': 476022007, 'type': 1, 'mid': 402207698, 'root': 0, 'parent': 0, 'dialog': 0, 'count': 14, 'rcount': 10, 'state': 0, 'fansgrade': 0, 'attr': 0, 'ctime': 1670849218, 'rpid_str': '141534734384', 'root_str': '0', 'parent_str': '0', 'like': 346, 'action': 0, 'member': {'mid': '402207698', 'uname': '碌暗华明', 'sex': '保密', 'sign': '不不不', 'avatar': 'https://i2.hdslb.com/bfs/face/74f09ecc8415410e166c307df74b64b3d11991f5.jpg', 'rank': '10000', 'face_nft_new': 0, 'is_senior_member': 0, 'level_info': {'current_level': 4, 'current_min': 0, 'current_exp': 0, 'next_exp': 0}, 'pendant': {'pid': 460, 'name': '异常生物', 'image': 'https://i2.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'expire': 0, 'image_enhance': 'https://i2.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'image_enhance_frame': ''}, 'nameplate': {'nid': 0, 'name': '', 'image': '', 'image_small': '', 'level': '', 'condition': ''}, 'official_verify': {'type': -1, 'desc': ''}, 'vip': {'vipType': 1, 'vipDueDate': 1628611200000, 'dueRemark': '', 'accessStatus': 0, 'vipStatus': 0, 'vipStatusWarn': '', 'themeType': 0, 'label': {'path': '', 'text': '', 'label_theme': '', 'text_color': '', 'bg_style': 0, 'bg_color': '', 'border_color': '', 'use_img_label': True, 'img_label_uri_hans': '', 'img_label_uri_hant': '', 'img_label_uri_hans_static': 'https://i0.hdslb.com/bfs/vip/d7b702ef65a976b20ed854cbd04cb9e27341bb79.png', 'img_label_uri_hant_static': 'https://i0.hdslb.com/bfs/activity-plat/static/20220614/e369244d0b14644f5e1a06431e22a4d5/KJunwh19T5.png'}, 'avatar_subscript': 0, 'nickname_color': ''}, 'fans_detail': None, 'user_sailing': {'pendant': {'id': 460, 'name': '异常生物', 'image': 'https://i0.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'jump_url': '', 'type': 'vip', 'image_enhance': 'https://i0.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'image_enhance_frame': ''}, 'cardbg': None, 'cardbg_with_focus': None}, 'is_contractor': False, 'contract_desc': '', 'nft_interaction': None, 'avatar_item': {'container_size': {'width': 1.8, 'height': 1.8}, 'fallback_layers': {'layers': [{'visible': True, 'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 0.787, 'height': 0.787}, 'render_spec': {'opacity': 1}}, 'layer_config': {'tags': {'AVATAR_LAYER': {}}, 'is_critical': True, 'layer_mask': {'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 0.787, 'height': 0.787}, 'render_spec': {'opacity': 1}}, 'mask_src': {'src_type': 3, 'draw': {'draw_type': 1, 'fill_mode': 1, 'color_config': {'day': {'argb': '#FF000000'}}}}}}, 'resource': {'res_type': 3, 'res_image': {'image_src': {'src_type': 1, 'placeholder': 6, 'remote': {'url': 'https://i2.hdslb.com/bfs/face/74f09ecc8415410e166c307df74b64b3d11991f5.jpg', 'bfs_style': 'widget-layer-avatar'}}}}}, {'visible': True, 'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 1.375, 'height': 1.375}, 'render_spec': {'opacity': 1}}, 'layer_config': {'tags': {'PENDENT_LAYER': {}}}, 'resource': {'res_type': 3, 'res_image': {'image_src': {'src_type': 1, 'remote': {'url': 'https://i2.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'bfs_style': 'widget-layer-avatar'}}}}}], 'is_critical_group': True}, 'mid': '402207698'}}, 'content': {'message': '好炫酷呀[星星眼]像好莱坞大片一样，作为原创动漫这质量真的可以啊[点赞]', 'members': [], 'emote': {'[星星眼]': {'id': 1956, 'package_id': 1, 'state': 0, 'type': 1, 'attr': 0, 'text': '[星星眼]', 'url': 'https://i0.hdslb.com/bfs/emote/63c9d1a31c0da745b61cdb35e0ecb28635675db2.png', 'meta': {'size': 1}, 'mtime': 1668688325, 'jump_title': '星星眼'}, '[点赞]': {'id': 25, 'package_id': 1, 'state': 0, 'type': 1 ...

# %%
r1 = r.json()
list(r1)
# Out:
# ['code', 'message', 'ttl', 'data']

# %%
data = r1.get('data')
print(list(data))
# Out:
# ['cursor', 'replies', 'top', 'top_replies', 'up_selection', 'effects', 'assist', 'blacklist', 'vote', 'config', 'upper', 'control', 'note', 'callbacks']

# %%
replies = data['replies']
for each in replies[0:1]:
    print(each)
# Out:
# {'rpid': 141534734384, 'oid': 476022007, 'type': 1, 'mid': 402207698, 'root': 0, 'parent': 0, 'dialog': 0, 'count': 14, 'rcount': 10, 'state': 0, 'fansgrade': 0, 'attr': 0, 'ctime': 1670849218, 'rpid_str': '141534734384', 'root_str': '0', 'parent_str': '0', 'like': 346, 'action': 0, 'member': {'mid': '402207698', 'uname': '碌暗华明', 'sex': '保密', 'sign': '不不不', 'avatar': 'https://i2.hdslb.com/bfs/face/74f09ecc8415410e166c307df74b64b3d11991f5.jpg', 'rank': '10000', 'face_nft_new': 0, 'is_senior_member': 0, 'level_info': {'current_level': 4, 'current_min': 0, 'current_exp': 0, 'next_exp': 0}, 'pendant': {'pid': 460, 'name': '异常生物', 'image': 'https://i2.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'expire': 0, 'image_enhance': 'https://i2.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'image_enhance_frame': ''}, 'nameplate': {'nid': 0, 'name': '', 'image': '', 'image_small': '', 'level': '', 'condition': ''}, 'official_verify': {'type': -1, 'desc': ''}, 'vip': {'vipType': 1, 'vipDueDate': 1628611200000, 'dueRemark': '', 'accessStatus': 0, 'vipStatus': 0, 'vipStatusWarn': '', 'themeType': 0, 'label': {'path': '', 'text': '', 'label_theme': '', 'text_color': '', 'bg_style': 0, 'bg_color': '', 'border_color': '', 'use_img_label': True, 'img_label_uri_hans': '', 'img_label_uri_hant': '', 'img_label_uri_hans_static': 'https://i0.hdslb.com/bfs/vip/d7b702ef65a976b20ed854cbd04cb9e27341bb79.png', 'img_label_uri_hant_static': 'https://i0.hdslb.com/bfs/activity-plat/static/20220614/e369244d0b14644f5e1a06431e22a4d5/KJunwh19T5.png'}, 'avatar_subscript': 0, 'nickname_color': ''}, 'fans_detail': None, 'user_sailing': {'pendant': {'id': 460, 'name': '异常生物', 'image': 'https://i0.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'jump_url': '', 'type': 'vip', 'image_enhance': 'https://i0.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'image_enhance_frame': ''}, 'cardbg': None, 'cardbg_with_focus': None}, 'is_contractor': False, 'contract_desc': '', 'nft_interaction': None, 'avatar_item': {'container_size': {'width': 1.8, 'height': 1.8}, 'fallback_layers': {'layers': [{'visible': True, 'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 0.787, 'height': 0.787}, 'render_spec': {'opacity': 1}}, 'layer_config': {'tags': {'AVATAR_LAYER': {}}, 'is_critical': True, 'layer_mask': {'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 0.787, 'height': 0.787}, 'render_spec': {'opacity': 1}}, 'mask_src': {'src_type': 3, 'draw': {'draw_type': 1, 'fill_mode': 1, 'color_config': {'day': {'argb': '#FF000000'}}}}}}, 'resource': {'res_type': 3, 'res_image': {'image_src': {'src_type': 1, 'placeholder': 6, 'remote': {'url': 'https://i2.hdslb.com/bfs/face/74f09ecc8415410e166c307df74b64b3d11991f5.jpg', 'bfs_style': 'widget-layer-avatar'}}}}}, {'visible': True, 'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 1.375, 'height': 1.375}, 'render_spec': {'opacity': 1}}, 'layer_config': {'tags': {'PENDENT_LAYER': {}}}, 'resource': {'res_type': 3, 'res_image': {'image_src': {'src_type': 1, 'remote': {'url': 'https://i2.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'bfs_style': 'widget-layer-avatar'}}}}}], 'is_critical_group': True}, 'mid': '402207698'}}, 'content': {'message': '好炫酷呀[星星眼]像好莱坞大片一样，作为原创动漫这质量真的可以啊[点赞]', 'members': [], 'emote': {'[星星眼]': {'id': 1956, 'package_id': 1, 'state': 0, 'type': 1, 'attr': 0, 'text': '[星星眼]', 'url': 'https://i0.hdslb.com/bfs/emote/63c9d1a31c0da745b61cdb35e0ecb28635675db2.png', 'meta': {'size': 1}, 'mtime': 1668688325, 'jump_title': '星星眼'}, '[点赞]': {'id': 25, 'package_id': 1, 'state': 0, 'type': 1, 'attr': 0, 'text': '[点赞]', 'url': 'https://i0.hdslb.com/bfs/emote/1a67265993913f4c35d15a6028a30724e83e7d35.png', 'meta': {'size': 1}, 'mtime': 1668688325, 'jump_title': '点赞'}}, 'jump_url': {}, 'max_l ...

# %%
replies_0 = replies[0]
print(type(replies_0))
print(list(replies_0))
# Out:
# <class 'dict'>
# ['rpid', 'oid', 'type', 'mid', 'root', 'parent', 'dialog', 'count', 'rcount', 'state', 'fansgrade', 'attr', 'ctime', 'rpid_str', 'root_str', 'parent_str', 'like', 'action', 'member', 'content', 'replies', 'assist', 'up_action', 'invisible', 'reply_control', 'folder', 'dynamic_id_str']

# %%
member = replies_0['member']
content = replies_0['content']
reply_control = replies_0['reply_control']
like = replies_0['like']
print(member)
r_replies = replies_0['replies']
# Out:
# {'mid': '402207698', 'uname': '碌暗华明', 'sex': '保密', 'sign': '不不不', 'avatar': 'https://i2.hdslb.com/bfs/face/74f09ecc8415410e166c307df74b64b3d11991f5.jpg', 'rank': '10000', 'face_nft_new': 0, 'is_senior_member': 0, 'level_info': {'current_level': 4, 'current_min': 0, 'current_exp': 0, 'next_exp': 0}, 'pendant': {'pid': 460, 'name': '异常生物', 'image': 'https://i2.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'expire': 0, 'image_enhance': 'https://i2.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'image_enhance_frame': ''}, 'nameplate': {'nid': 0, 'name': '', 'image': '', 'image_small': '', 'level': '', 'condition': ''}, 'official_verify': {'type': -1, 'desc': ''}, 'vip': {'vipType': 1, 'vipDueDate': 1628611200000, 'dueRemark': '', 'accessStatus': 0, 'vipStatus': 0, 'vipStatusWarn': '', 'themeType': 0, 'label': {'path': '', 'text': '', 'label_theme': '', 'text_color': '', 'bg_style': 0, 'bg_color': '', 'border_color': '', 'use_img_label': True, 'img_label_uri_hans': '', 'img_label_uri_hant': '', 'img_label_uri_hans_static': 'https://i0.hdslb.com/bfs/vip/d7b702ef65a976b20ed854cbd04cb9e27341bb79.png', 'img_label_uri_hant_static': 'https://i0.hdslb.com/bfs/activity-plat/static/20220614/e369244d0b14644f5e1a06431e22a4d5/KJunwh19T5.png'}, 'avatar_subscript': 0, 'nickname_color': ''}, 'fans_detail': None, 'user_sailing': {'pendant': {'id': 460, 'name': '异常生物', 'image': 'https://i0.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'jump_url': '', 'type': 'vip', 'image_enhance': 'https://i0.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'image_enhance_frame': ''}, 'cardbg': None, 'cardbg_with_focus': None}, 'is_contractor': False, 'contract_desc': '', 'nft_interaction': None, 'avatar_item': {'container_size': {'width': 1.8, 'height': 1.8}, 'fallback_layers': {'layers': [{'visible': True, 'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 0.787, 'height': 0.787}, 'render_spec': {'opacity': 1}}, 'layer_config': {'tags': {'AVATAR_LAYER': {}}, 'is_critical': True, 'layer_mask': {'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 0.787, 'height': 0.787}, 'render_spec': {'opacity': 1}}, 'mask_src': {'src_type': 3, 'draw': {'draw_type': 1, 'fill_mode': 1, 'color_config': {'day': {'argb': '#FF000000'}}}}}}, 'resource': {'res_type': 3, 'res_image': {'image_src': {'src_type': 1, 'placeholder': 6, 'remote': {'url': 'https://i2.hdslb.com/bfs/face/74f09ecc8415410e166c307df74b64b3d11991f5.jpg', 'bfs_style': 'widget-layer-avatar'}}}}}, {'visible': True, 'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 1.375, 'height': 1.375}, 'render_spec': {'opacity': 1}}, 'layer_config': {'tags': {'PENDENT_LAYER': {}}}, 'resource': {'res_type': 3, 'res_image': {'image_src': {'src_type': 1, 'remote': {'url': 'https://i2.hdslb.com/bfs/face/a959c72407b2ac553d4328fd76d55d0134e20f65.png', 'bfs_style': 'widget-layer-avatar'}}}}}], 'is_critical_group': True}, 'mid': '402207698'}}

# %%
print(like)
print('-'*100)
print(content)
print('-'*100)
print(reply_control)
# Out:
# 346
# ----------------------------------------------------------------------------------------------------
# {'message': '好炫酷呀[星星眼]像好莱坞大片一样，作为原创动漫这质量真的可以啊[点赞]', 'members': [], 'emote': {'[星星眼]': {'id': 1956, 'package_id': 1, 'state': 0, 'type': 1, 'attr': 0, 'text': '[星星眼]', 'url': 'https://i0.hdslb.com/bfs/emote/63c9d1a31c0da745b61cdb35e0ecb28635675db2.png', 'meta': {'size': 1}, 'mtime': 1668688325, 'jump_title': '星星眼'}, '[点赞]': {'id': 25, 'package_id': 1, 'state': 0, 'type': 1, 'attr': 0, 'text': '[点赞]', 'url': 'https://i0.hdslb.com/bfs/emote/1a67265993913f4c35d15a6028a30724e83e7d35.png', 'meta': {'size': 1}, 'mtime': 1668688325, 'jump_title': '点赞'}}, 'jump_url': {}, 'max_line': 6}
# ----------------------------------------------------------------------------------------------------
# {'sub_reply_entry_text': '共10条回复', 'sub_reply_title_text': '相关回复共10条', 'time_desc': '21天前发布'}

# %%
print(r_replies)
# Out:
# [{'rpid': 141535129216, 'oid': 476022007, 'type': 1, 'mid': 382954857, 'root': 141534734384, 'parent': 141534734384, 'dialog': 141535129216, 'count': 0, 'rcount': 0, 'state': 0, 'fansgrade': 0, 'attr': 0, 'ctime': 1670849363, 'rpid_str': '141535129216', 'root_str': '141534734384', 'parent_str': '141534734384', 'like': 14, 'action': 0, 'member': {'mid': '382954857', 'uname': '傻孩子引着了火堆', 'sex': '保密', 'sign': '', 'avatar': 'https://i0.hdslb.com/bfs/baselabs/f0191aadc9f61bdcd5fb798ca481c6a49a58a42c.png', 'rank': '10000', 'face_nft_new': 1, 'is_senior_member': 0, 'level_info': {'current_level': 5, 'current_min': 0, 'current_exp': 0, 'next_exp': 0}, 'pendant': {'pid': 0, 'name': '', 'image': '', 'expire': 0, 'image_enhance': '', 'image_enhance_frame': ''}, 'nameplate': {'nid': 0, 'name': '', 'image': '', 'image_small': '', 'level': '', 'condition': ''}, 'official_verify': {'type': -1, 'desc': ''}, 'vip': {'vipType': 1, 'vipDueDate': 1656864000000, 'dueRemark': '', 'accessStatus': 0, 'vipStatus': 0, 'vipStatusWarn': '', 'themeType': 0, 'label': {'path': '', 'text': '', 'label_theme': '', 'text_color': '', 'bg_style': 0, 'bg_color': '', 'border_color': '', 'use_img_label': True, 'img_label_uri_hans': '', 'img_label_uri_hant': '', 'img_label_uri_hans_static': 'https://i0.hdslb.com/bfs/vip/d7b702ef65a976b20ed854cbd04cb9e27341bb79.png', 'img_label_uri_hant_static': 'https://i0.hdslb.com/bfs/activity-plat/static/20220614/e369244d0b14644f5e1a06431e22a4d5/KJunwh19T5.png'}, 'avatar_subscript': 0, 'nickname_color': ''}, 'fans_detail': None, 'user_sailing': {'pendant': None, 'cardbg': None, 'cardbg_with_focus': None}, 'is_contractor': False, 'contract_desc': '', 'nft_interaction': {'region': {'type': 1, 'icon': 'https://i0.hdslb.com/bfs/activity-plat/static/20220506/334553dd7c506a92b88eaf4d59ac8b4d/j8AeXAkEul.gif', 'show_status': 1}}, 'avatar_item': {'container_size': {'width': 1.8, 'height': 1.8}, 'fallback_layers': {'layers': [{'visible': True, 'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 1.3, 'height': 1.3}, 'render_spec': {'opacity': 1}}, 'layer_config': {'tags': {'AVATAR_LAYER': {}}, 'is_critical': True, 'layer_mask': {'general_spec': {'pos_spec': {'coordinate_pos': 2, 'axis_x': 0.9, 'axis_y': 0.9}, 'size_spec': {'width': 1.3, 'height': 1.3}, 'render_spec': {'opacity': 1}}, 'mask_src': {'src_type': 3, 'draw': {'draw_type': 1, 'fill_mode': 1, 'color_config': {'day': {'argb': '#FF000000'}}}}}}, 'resource': {'res_type': 3, 'res_image': {'image_src': {'src_type': 1, 'placeholder': 6, 'remote': {'url': 'https://i0.hdslb.com/bfs/baselabs/f0191aadc9f61bdcd5fb798ca481c6a49a58a42c.png', 'bfs_style': 'widget-layer-avatar'}}}}}, {'visible': True, 'general_spec': {'pos_spec': {'coordinate_pos': 1, 'axis_x': 1.1833333333333333, 'axis_y': 1.1833333333333333}, 'size_spec': {'width': 0.39999999999999997, 'height': 0.39999999999999997}, 'render_spec': {'opacity': 1}}, 'layer_config': {'tags': {'ICON_LAYER': {}}}, 'resource': {'res_type': 5, 'res_native_draw': {'draw_src': {'src_type': 3, 'draw': {'draw_type': 1, 'fill_mode': 1, 'color_config': {'is_dark_mode_aware': True, 'day': {'argb': '#FFFFFFFF'}, 'night': {'argb': '#FF17181A'}}}}}}}, {'visible': True, 'general_spec': {'pos_spec': {'coordinate_pos': 1, 'axis_x': 1.2166666666666668, 'axis_y': 1.2166666666666668}, 'size_spec': {'width': 0.3333333333333333, 'height': 0.3333333333333333}, 'render_spec': {'opacity': 1}}, 'layer_config': {'tags': {'ICON_LAYER': {}}}, 'resource': {'res_type': 4, 'res_animation': {'webp_src': {'src_type': 1, 'placeholder': 5, 'remote': {'url': 'https://i0.hdslb.com/bfs/activity-plat/static/20220506/334553dd7c506a92b88eaf4d59ac8b4d/j8AeXAkEul.gif', 'bfs_style': 'widget-layer-avatar'}}}}}], 'is_critical_group': True}, 'mid': '382954857'}}, 'content': {'message': '高情商', 'members': [], 'jump_url': {}, 'max_line': 999}, 'replies': None, 'assist': 0, 'up_action': {'like': False, 'reply': False}, 'invisible': False, 'reply_ ...

# %%
len(r_replies)
# Out:
# 3
